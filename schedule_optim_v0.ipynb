# %% [markdown]
# # 0. Install Dependencies

# %%
# %pip install tensorflow
# %pip install gymnasium
# %pip install keras
# %pip install keras-rl2
# %pip install stable-baselines3
# %pip install tensorboard

# %% [markdown]
# # 1. Define the network scheduling environment

# %%
import gymnasium as gym
from gymnasium import Env
from gymnasium.spaces import Discrete, Box
import numpy as np
import random
import os
from stable_baselines3 import DQN, PPO, A2C
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.results_plotter import plot_results, load_results

# %load_ext autoreload
# %autoreload 2

# %%
from gymnasium import spaces
import numpy as np

class FlightSchedulingEnv(gym.Env):
    def __init__(self, departure_times, arrival_times, max_steps=100):
        super(FlightSchedulingEnv, self).__init__()
        self.number_of_flights = len(departure_times)
        # Définir l'espace d'action et d'observation
        self.action_space = spaces.Discrete(self.number_of_flights*2 + 1) 
        self.observation_space = spaces.Box(
            low=np.zeros(self.number_of_flights), 
            high=np.array([3000 for _ in range(self.number_of_flights)])
        )

        # Initialiser les détails des vols
        self.departure_times = departure_times  # Heures de départ initiales
        self.arrival_times = arrival_times  # Heures d'arrivée initiales

        # Initialiser les contraintes
        self.constraints = {i: [0, 2000] for i in range(self.number_of_flights)}
        
        # Initialiser l'état actuel
        self.current_state = np.array(self.departure_times)

        # Autres paramètres du problème
        self.time_step = 20  # Multiple de 20 minutes
        self.max_steps = max_steps  # Limite d'étapes
        self.current_step = 0

    def reset(self, seed = None, options = None):
        super().reset(seed=seed)
        self.current_state = np.array(self.departure_times)
        self.current_step = 0
        return self.current_state, {}

    def step(self, action):
        old_revenue = self.calculate_revenue()
        # Mettez à jour l'état en déplaçant le vol correspondant
        if action == self.number_of_flights * 2:
            pass
        else:
            if action % 2 == 0:
            # Si l'action est paire, ajoutez self.time_step
                new_departure_time = self.current_state[action // 2] + self.time_step
            else:
            # Si l'action est impaire, soustrayez self.time_step
                new_departure_time = self.current_state[action // 2] - self.time_step
            
            # Assurer que les heures de départ respectent les contraintes
            if self.respect_constraints(action // 2, new_departure_time):
                self.current_state[action // 2] = new_departure_time
          
        # Calculer le revenu du nouveau planning
        new_revenue = self.calculate_revenue()
        # Calculer la récompense comme la variation de revenu
        reward = new_revenue - old_revenue

        # Vérifier si la limite d'étapes est atteinte
        done = self.current_step == self.max_steps

        # Mettre à jour le nombre d'étapes
        self.current_step += 1

        # Retourner l'observation, la récompense, l'état terminal et des informations supplémentaires
        return self.current_state.copy(), reward, done, False, {}

    def calculate_revenue(self):
        # Appeler la fonction existante pour calculer le revenu du planning actuel
        return np.sum(self.current_state)
    
    def respect_constraints(self, flight_number, departure_time): 
        min_departure, max_departure = self.constraints[flight_number]
        return min_departure <= departure_time <= max_departure

# %% [markdown]
# # 2. Random policy

# %%
departure_times = [8 * 60, 9 * 60, 10 * 60, 12 * 60, 14 * 60]  # Heures de départ initiales
arrival_times = [10 * 60, 11 * 60, 12 * 60, 14 * 60, 16 * 60]  # Heures d'arrivée initiales
# Exemple d'utilisation de l'environnement

env = FlightSchedulingEnv(departure_times, arrival_times, max_steps=1000)

# Réinitialiser l'environnement
obs = env.reset()

# Exemple d'itération sur les étapes
for _ in range(10):
    action = env.action_space.sample()  # Action aléatoire
    obs, reward, done, truncated, _ = env.step(action)
    print("Observation:", obs, "Reward:", reward)

env.close()
# Out:
# Observation: [460 540 600 720 840] Reward: -20
# Observation: [460 540 600 720 820] Reward: -20
# Observation: [460 540 620 720 820] Reward: 20
# Observation: [460 540 620 720 840] Reward: 20
# Observation: [440 540 620 720 840] Reward: -20
# Observation: [440 520 620 720 840] Reward: -20
# Observation: [440 520 620 720 840] Reward: 0
# Observation: [420 520 620 720 840] Reward: -20
# Observation: [420 520 620 700 840] Reward: -20
# Observation: [420 520 620 700 840] Reward: 0

# %% [markdown]
# # 3. Learn a policy using RL

# %%
# Créer une instance de l'environnement personnalisé
#departure_times = [8 * 60]  # Heures de départ initiales
#arrival_times = [10 * 60]  # Heures d'arrivée initiales
departure_times = [8 * 60, 9 * 60, 10 * 60, 12 * 60, 14 * 60]  # Heures de départ initiales
arrival_times = [10 * 60, 11 * 60, 12 * 60, 14 * 60, 16 * 60]  # Heures d'arrivée initiales
#departure_times = [8 * 60 for _ in range(20)]  # Heures de départ initiales
#arrival_times = [10 * 60 for _ in range(20)]  # Heures d'arrivée initiales

# %%
env = FlightSchedulingEnv(departure_times=departure_times, arrival_times=arrival_times, max_steps=1000)
env = DummyVecEnv([lambda: env])

#model = A2C("MlpPolicy", env, verbose=1)
model = PPO("MlpPolicy", env, verbose=1)
#model = DQN("MlpPolicy", env, verbose=1)
# Entraîner le modèle sur un certain nombre d'itérations
model.learn(total_timesteps=100000)

# Tester le modèle entraîné
obs = env.reset()
for _ in range(3):
    obs = env.reset()
    done = False
    while not done:
        action, _ = model.predict(obs)
        obs, reward, done, _ = env.step(action)
        print(obs)
        print(reward)
env.close()
# Out:
# Using cpu device
# -----------------------------
# | time/              |      |
# |    fps             | 1693 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1146        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.019606844 |
# |    clip_fraction        | 0.464       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.38       |
# |    explained_variance   | 0.000933    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 874         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0576     |
# |    value_loss           | 2.7e+03     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1044        |
# |    iterations           | 3           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.020428775 |
# |    clip_fraction        | 0.39        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.33       |
# |    explained_variance   | -0.00718    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.41e+03    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0472     |
# |    value_loss           | 3.54e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 948         |
# |    iterations           | 4           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.018812899 |
# |    clip_fraction        | 0.372       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.27       |
# |    explained_variance   | 0.000253    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 698         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0278     |
# |    value_loss           | 2.07e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 900         |
# |    iterations           | 5           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009553771 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.22       |
# |    explained_variance   | 0.00446     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 406         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.019      |
# |    value_loss           | 785         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 869        |
# |    iterations           | 6          |
# |    time_elapsed         | 14         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.00895035 |
# |    clip_fraction        | 0.0539     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.16      |
# |    explained_variance   | 0.0181     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 230        |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.0159    |
# |    value_loss           | 530        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 848         |
# |    iterations           | 7           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.019997863 |
# |    clip_fraction        | 0.278       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.09       |
# |    explained_variance   | 0.0166      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 227         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00755    |
# |    value_loss           | 429         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 834        |
# |    iterations           | 8          |
# |    time_elapsed         | 19         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.00809524 |
# |    clip_fraction        | 0.156      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.97      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 75.6       |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.00832   |
# |    value_loss           | 235        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 824         |
# |    iterations           | 9           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.007334506 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.93       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 104         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00769    |
# |    value_loss           | 183         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 815         |
# |    iterations           | 10          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.008489607 |
# |    clip_fraction        | 0.0859      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.84       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 65.9        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00666    |
# |    value_loss           | 115         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 807         |
# |    iterations           | 11          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.010572568 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.81       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 46          |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0107     |
# |    value_loss           | 92          |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 799          |
# |    iterations           | 12           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0123516675 |
# |    clip_fraction        | 0.109        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.79        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34.4         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.0113      |
# |    value_loss           | 66.5         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 792          |
# |    iterations           | 13           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0105907265 |
# |    clip_fraction        | 0.147        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.76        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 30.8         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00777     |
# |    value_loss           | 61.2         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 788          |
# |    iterations           | 14           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0045431284 |
# |    clip_fraction        | 0.0792       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.74        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20.8         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00423     |
# |    value_loss           | 42.6         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 783          |
# |    iterations           | 15           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0083227325 |
# |    clip_fraction        | 0.12         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.7         |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.4         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00723     |
# |    value_loss           | 25.8         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 779         |
# |    iterations           | 16          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.014451809 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.66       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.03        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00894    |
# |    value_loss           | 15.2        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 783        |
# |    iterations           | 17         |
# |    time_elapsed         | 44         |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.00995972 |
# |    clip_fraction        | 0.106      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.64      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.95       |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.00512   |
# |    value_loss           | 10.4       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 788         |
# |    iterations           | 18          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.008752869 |
# |    clip_fraction        | 0.0966      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.51       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.8         |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0029     |
# |    value_loss           | 22.5        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 793          |
# |    iterations           | 19           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0151272705 |
# |    clip_fraction        | 0.17         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.49        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.43         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00281     |
# |    value_loss           | 5.21         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 798         |
# |    iterations           | 20          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.016765745 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.5        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.194       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0076     |
# |    value_loss           | 5.78        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 803         |
# |    iterations           | 21          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.015489008 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.53       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.4        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00374    |
# |    value_loss           | 9.86        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 804         |
# |    iterations           | 22          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.013253523 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.53       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.77        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00412    |
# |    value_loss           | 6.52        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 807          |
# |    iterations           | 23           |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0124425795 |
# |    clip_fraction        | 0.165        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.56        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0602       |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00455     |
# |    value_loss           | 0.795        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 809         |
# |    iterations           | 24          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.
# [0.]
# [[2000. 2000. 1000. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1000. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1000. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1000. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1000. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1000. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1000. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1000. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1000. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1000. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1000. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1000. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1000. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1000. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1000. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1000. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1000. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1000. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1000. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1000. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1000. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1000. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1000. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1000. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1000. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1000. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1000. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1000. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1000. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1000. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1000. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1000. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1000. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1000. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1000. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1000. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1000. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1000. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1000. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1000. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1000. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1020. 2000. 2000.]]
# [20.]
# [[2000. 2000. 1020. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1020. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1020. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1020. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1020. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1020. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1020. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1020. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1020. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1020. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1020. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1020. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1020. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1020. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1020. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1020. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1020. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1020. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1020. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1020. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1020. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1020. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1020. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1040. 2000. 2000.]]
# [20.]
# [[2000. 2000. 1040. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1040. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1040. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1040. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1040. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1040. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1040. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1040. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1040. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1040. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1040. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1040. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1040. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1040. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1040. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1040. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1040. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1060. 2000. 2000.]]
# [20.]
# [[2000. 2000. 1060. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1060. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1060. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1060. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1060. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1060. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1060. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1060. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1060. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1060. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1060. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1060. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1060. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1060. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1060. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1060. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1060. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1060. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1060. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1060. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1060. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1060. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1060. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1060. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1060. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1060. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1060. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1060. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1060. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1060. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1060. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1080. 2000. 2000.]]
# [20.]
# [[2000. 2000. 1080. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1080. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1080. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1080. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1080. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1080. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1100. 2000. 2000.]]
# [20.]
# [[2000. 2000. 1100. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1100. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1100. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1100. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1100. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1100. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1100. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1100. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1100. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1100. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1100. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1100. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1100. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1100. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1100. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1100. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1100. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1100. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1100. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1100. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1100. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1100. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1100. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1100. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1100. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1100. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1100. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1100. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1100. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1100. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1100. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1100. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1100. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1100. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1100. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1100. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1100. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1100. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1100. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1100. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1100. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1100. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1100. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1100. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1100. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1100. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1120. 2000. 2000.]]
# [20.]
# [[2000. 2000. 1120. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1120. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1120. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1120. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1120. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1120. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1120. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1120. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1120. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1120. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1120. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1120. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1120. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1120. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1120. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1120. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1120. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1120. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1120. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1120. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1120. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1120. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1120. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1120. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1120. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1120. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1120. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1120. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1120. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1120. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1120. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1120. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1120. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1120. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1120. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1140. 2000. 2000.]]
# [20.]
# [[2000. 2000. 1140. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1140. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1140. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1140. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1140. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1140. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1140. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1140. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1140. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1140. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1140. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1140. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1140. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1140. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1140. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1140. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1140. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1140. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1140. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1140. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1140. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1140. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1140. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1140. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1140. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1140. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1140. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1140. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1140. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1140. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1140. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1140. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1140. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1140. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1140. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1140. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1140. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1140. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1140. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1140. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1140. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1140. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [20.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1160. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1180. 2000. 2000.]]
# [20.]
# [[2000. 2000. 1180. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1180. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1180. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1180. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1180. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1180. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1180. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1180. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1180. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1180. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1180. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1180. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1180. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1180. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1180. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1180. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1180. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1180. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1180. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1180. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1180. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1180. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1180. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1180. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1180. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1180. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1180. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1180. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1180. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1180. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1180. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1180. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1180. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1180. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1180. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1180. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1180. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1180. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1180. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1180. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1180. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1180. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1180. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1180. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1180. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1180. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1180. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1180. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1200. 2000. 2000.]]
# [20.]
# [[2000. 2000. 1200. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1200. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1200. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1200. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1200. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1200. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1200. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1200. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1200. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1200. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1200. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1200. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1200. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1200. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1200. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1200. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1200. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1200. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1220. 2000. 2000.]]
# [20.]
# [[2000. 2000. 1220. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1220. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1220. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1220. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1220. 2000. 2000.]]
# [0.]
# [[2000. 2000. 1220. 2000. 2000.]]
# [0.]

# %%
for _ in range(1):
    obs = env.reset()
    total_reward = 0
    done = False
    while not done:
        action, _ = model.predict(obs)
        #action = [0]
        obs, reward, done, _ = env.step(action)
        #print('action : ', action[0])
        print('obs : ', obs[0])
        #print('reward : ', reward[0])
        total_reward += reward
    print(total_reward)
env.close()
# Out:
# obs :  [480. 540. 600. 740. 840.]
# obs :  [480. 540. 600. 740. 840.]
# obs :  [480. 540. 600. 740. 860.]
# obs :  [500. 540. 600. 740. 860.]
# obs :  [500. 560. 600. 740. 860.]
# obs :  [520. 560. 600. 740. 860.]
# obs :  [520. 560. 600. 740. 880.]
# obs :  [540. 560. 600. 740. 880.]
# obs :  [540. 560. 600. 740. 880.]
# obs :  [540. 580. 600. 740. 880.]
# obs :  [540. 600. 600. 740. 880.]
# obs :  [540. 620. 600. 740. 880.]
# obs :  [540. 620. 620. 740. 880.]
# obs :  [560. 620. 620. 740. 880.]
# obs :  [580. 620. 620. 740. 880.]
# obs :  [580. 620. 620. 740. 880.]
# obs :  [580. 640. 620. 740. 880.]
# obs :  [580. 640. 620. 740. 900.]
# obs :  [580. 640. 620. 740. 900.]
# obs :  [600. 640. 620. 740. 900.]
# obs :  [600. 660. 620. 740. 900.]
# obs :  [620. 660. 620. 740. 900.]
# obs :  [620. 660. 620. 740. 900.]
# obs :  [620. 660. 620. 740. 900.]
# obs :  [640. 660. 620. 740. 900.]
# obs :  [640. 660. 620. 760. 900.]
# obs :  [640. 660. 620. 760. 920.]
# obs :  [640. 660. 620. 760. 920.]
# obs :  [640. 680. 620. 760. 920.]
# obs :  [660. 680. 620. 760. 920.]
# obs :  [660. 700. 620. 760. 920.]
# obs :  [660. 700. 620. 760. 920.]
# obs :  [660. 720. 620. 760. 920.]
# obs :  [680. 720. 620. 760. 920.]
# obs :  [680. 740. 620. 760. 920.]
# obs :  [700. 740. 620. 760. 920.]
# obs :  [720. 740. 620. 760. 920.]
# obs :  [720. 760. 620. 760. 920.]
# obs :  [740. 760. 620. 760. 920.]
# obs :  [740. 760. 640. 760. 920.]
# obs :  [760. 760. 640. 760. 920.]
# obs :  [780. 760. 640. 760. 920.]
# obs :  [780. 760. 640. 760. 940.]
# obs :  [780. 760. 660. 760. 940.]
# obs :  [780. 760. 660. 780. 940.]
# obs :  [800. 760. 660. 780. 940.]
# obs :  [800. 760. 660. 780. 960.]
# obs :  [820. 760. 660. 780. 960.]
# obs :  [820. 780. 660. 780. 960.]
# obs :  [840. 780. 660. 780. 960.]
# obs :  [840. 800. 660. 780. 960.]
# obs :  [860. 800. 660. 780. 960.]
# obs :  [860. 800. 660. 800. 960.]
# obs :  [860. 820. 660. 800. 960.]
# obs :  [860. 840. 660. 800. 960.]
# obs :  [860. 840. 660. 800. 960.]
# obs :  [860. 840. 660. 800. 980.]
# obs :  [860. 860. 660. 800. 980.]
# obs :  [860. 880. 660. 800. 980.]
# obs :  [880. 880. 660. 800. 980.]
# obs :  [880. 900. 660. 800. 980.]
# obs :  [ 880.  900.  660.  800. 1000.]
# obs :  [ 900.  900.  660.  800. 1000.]
# obs :  [ 900.  900.  660.  800. 1020.]
# obs :  [ 920.  900.  660.  800. 1020.]
# obs :  [ 920.  900.  660.  800. 1040.]
# obs :  [ 920.  900.  660.  800. 1060.]
# obs :  [ 940.  900.  660.  800. 1060.]
# obs :  [ 940.  900.  660.  820. 1060.]
# obs :  [ 940.  900.  660.  820. 1080.]
# obs :  [ 960.  900.  660.  820. 1080.]
# obs :  [ 960.  900.  660.  820. 1080.]
# obs :  [ 960.  900.  660.  820. 1100.]
# obs :  [ 960.  900.  660.  820. 1100.]
# obs :  [ 960.  920.  660.  820. 1100.]
# obs :  [ 960.  940.  660.  820. 1100.]
# obs :  [ 960.  940.  660.  840. 1100.]
# obs :  [ 960.  960.  660.  840. 1100.]
# obs :  [ 960.  980.  660.  840. 1100.]
# obs :  [ 980.  980.  660.  840. 1100.]
# obs :  [ 980.  980.  660.  860. 1100.]
# obs :  [ 980. 1000.  660.  860. 1100.]
# obs :  [ 980. 1020.  660.  860. 1100.]
# obs :  [1000. 1020.  660.  860. 1100.]
# obs :  [1000. 1020.  660.  860. 1120.]
# obs :  [1000. 1020.  660.  860. 1120.]
# obs :  [1000. 1020.  660.  880. 1120.]
# obs :  [1000. 1040.  660.  880. 1120.]
# obs :  [1000. 1060.  660.  880. 1120.]
# obs :  [1000. 1080.  660.  880. 1120.]
# obs :  [1000. 1080.  660.  880. 1140.]
# obs :  [1020. 1080.  660.  880. 1140.]
# obs :  [1020. 1080.  660.  880. 1160.]
# obs :  [1020. 1080.  660.  900. 1160.]
# obs :  [1020. 1080.  660.  900. 1180.]
# obs :  [1040. 1080.  660.  900. 1180.]
# obs :  [1040. 1080.  660.  920. 1180.]
# obs :  [1040. 1080.  660.  920. 1180.]
# obs :  [1060. 1080.  660.  920. 1180.]
# obs :  [1060. 1080.  660.  920. 1180.]
# obs :  [1080. 1080.  660.  920. 1180.]
# obs :  [1080. 1080.  680.  920. 1180.]
# obs :  [1100. 1080.  680.  920. 1180.]
# obs :  [1100. 1080.  680.  940. 1180.]
# obs :  [1100. 1080.  680.  940. 1200.]
# obs :  [1100. 1080.  680.  940. 1200.]
# obs :  [1120. 1080.  680.  940. 1200.]
# obs :  [1140. 1080.  680.  940. 1200.]
# obs :  [1140. 1100.  680.  940. 1200.]
# obs :  [1140. 1100.  680.  960. 1200.]
# obs :  [1140. 1100.  680.  960. 1200.]
# obs :  [1140. 1100.  680.  960. 1200.]
# obs :  [1140. 1100.  680.  960. 1200.]
# obs :  [1140. 1120.  680.  960. 1200.]
# obs :  [1160. 1120.  680.  960. 1200.]
# obs :  [1160. 1120.  680.  960. 1200.]
 2000.]
# obs :  [2000. 2000.  880. 1720. 2000.]
# obs :  [2000. 2000.  880. 1720. 2000.]
# obs :  [2000. 2000.  880. 1720. 2000.]
# obs :  [2000. 2000.  880. 1720. 2000.]
# obs :  [2000. 2000.  880. 1720. 2000.]
# obs :  [2000. 2000.  880. 1720. 2000.]
# obs :  [2000. 2000.  880. 1720. 2000.]
# obs :  [2000. 2000.  880. 1720. 2000.]
# obs :  [2000. 2000.  880. 1720. 2000.]
# obs :  [2000. 2000.  880. 1720. 2000.]
# obs :  [2000. 2000.  880. 1740. 2000.]
# obs :  [2000. 2000.  880. 1740. 2000.]
# obs :  [2000. 2000.  880. 1740. 2000.]
# obs :  [2000. 2000.  880. 1740. 2000.]
# obs :  [2000. 2000.  880. 1740. 2000.]
# obs :  [2000. 2000.  880. 1740. 2000.]
# obs :  [2000. 2000.  880. 1760. 2000.]
# obs :  [2000. 2000.  900. 1760. 2000.]
# obs :  [2000. 2000.  900. 1760. 2000.]
# obs :  [2000. 2000.  900. 1780. 2000.]
# obs :  [2000. 2000.  900. 1780. 2000.]
# obs :  [2000. 2000.  900. 1800. 2000.]
# obs :  [2000. 2000.  900. 1800. 2000.]
# obs :  [2000. 2000.  920. 1800. 2000.]
# obs :  [2000. 2000.  940. 1800. 2000.]
# obs :  [2000. 2000.  940. 1800. 2000.]
# obs :  [2000. 2000.  940. 1800. 2000.]
# obs :  [2000. 2000.  940. 1800. 2000.]
# obs :  [2000. 2000.  940. 1800. 2000.]
# obs :  [2000. 2000.  940. 1800. 2000.]
# obs :  [2000. 2000.  940. 1800. 2000.]
# obs :  [2000. 2000.  940. 1800. 2000.]
# obs :  [2000. 2000.  940. 1800. 2000.]
# obs :  [2000. 2000.  940. 1800. 2000.]
# obs :  [2000. 2000.  940. 1800. 2000.]
# obs :  [2000. 2000.  940. 1820. 2000.]
# obs :  [2000. 2000.  940. 1820. 2000.]
# obs :  [2000. 2000.  940. 1820. 2000.]
# obs :  [2000. 2000.  940. 1820. 2000.]
# obs :  [2000. 2000.  940. 1820. 2000.]
# obs :  [2000. 2000.  940. 1820. 2000.]
# obs :  [2000. 2000.  940. 1820. 2000.]
# obs :  [2000. 2000.  940. 1840. 2000.]
# obs :  [2000. 2000.  940. 1860. 2000.]
# obs :  [2000. 2000.  940. 1860. 2000.]
# obs :  [2000. 2000.  940. 1860. 2000.]
# obs :  [2000. 2000.  940. 1860. 2000.]
# obs :  [2000. 2000.  940. 1860. 2000.]
# obs :  [2000. 2000.  940. 1860. 2000.]
# obs :  [2000. 2000.  940. 1880. 2000.]
# obs :  [2000. 2000.  940. 1880. 2000.]
# obs :  [2000. 2000.  940. 1880. 2000.]
# obs :  [2000. 2000.  940. 1880. 2000.]
# obs :  [2000. 2000.  940. 1880. 2000.]
# obs :  [2000. 2000.  940. 1880. 2000.]
# obs :  [2000. 2000.  940. 1880. 2000.]
# obs :  [2000. 2000.  940. 1880. 2000.]
# obs :  [2000. 2000.  940. 1880. 2000.]
# obs :  [2000. 2000.  940. 1880. 2000.]
# obs :  [2000. 2000.  940. 1900. 2000.]
# obs :  [2000. 2000.  940. 1900. 2000.]
# obs :  [2000. 2000.  940. 1920. 2000.]
# obs :  [2000. 2000.  960. 1920. 2000.]
# obs :  [2000. 2000.  960. 1920. 2000.]
# obs :  [2000. 2000.  960. 1920. 2000.]
# obs :  [2000. 2000.  960. 1920. 2000.]
# obs :  [2000. 2000.  960. 1920. 2000.]
# obs :  [2000. 2000.  960. 1920. 2000.]
# obs :  [2000. 2000.  960. 1940. 2000.]
# obs :  [2000. 2000.  960. 1940. 2000.]
# obs :  [2000. 2000.  960. 1960. 2000.]
# obs :  [2000. 2000.  960. 1960. 2000.]
# obs :  [2000. 2000.  960. 1960. 2000.]
# obs :  [2000. 2000.  960. 1960. 2000.]
# obs :  [2000. 2000.  960. 1960. 2000.]
# obs :  [2000. 2000.  960. 1960. 2000.]
# obs :  [2000. 2000.  960. 1960. 2000.]
# obs :  [2000. 2000.  960. 1960. 2000.]
# obs :  [2000. 2000.  960. 1960. 2000.]
# obs :  [2000. 2000.  960. 1980. 2000.]
# obs :  [2000. 2000.  960. 1980. 2000.]
# obs :  [2000. 2000.  960. 1980. 2000.]
# obs :  [2000. 2000.  960. 1980. 2000.]
# obs :  [2000. 2000.  960. 1980. 2000.]
# obs :  [2000. 2000.  960. 1980. 2000.]
# obs :  [2000. 2000.  960. 1980. 2000.]
# obs :  [2000. 2000.  960. 1980. 2000.]
# obs :  [2000. 2000.  960. 1980. 2000.]
# obs :  [2000. 2000.  960. 1980. 2000.]
# obs :  [2000. 2000.  960. 2000. 2000.]
# obs :  [2000. 2000.  960. 2000. 2000.]
# obs :  [2000. 2000.  960. 2000. 2000.]
# obs :  [2000. 2000.  960. 2000. 2000.]
# obs :  [2000. 2000.  960. 2000. 2000.]
# obs :  [2000. 2000.  960. 2000. 2000.]
# obs :  [2000. 2000.  960. 2000. 2000.]
# obs :  [2000. 2000.  960. 2000. 2000.]
# obs :  [2000. 2000.  960. 2000. 2000.]
# obs :  [2000. 2000.  960. 2000. 2000.]
# obs :  [2000. 2000.  960. 2000. 2000.]
# obs :  [2000. 2000.  960. 2000. 2000.]
# obs :  [2000. 2000.  960. 2000. 2000.]
# obs :  [2000. 2000.  960. 2000. 2000.]
# obs :  [2000. 2000.  960. 2000. 2000.]
# obs :  [2000. 2000.  960. 2000. 2000.]
# obs :  [2000. 2000.  960. 2000. 2000.]
# obs :  [2000. 2000.  960. 2000. 2000.]
# obs :  [2000. 2000.  960. 2000. 2000.]
# obs :  [2000. 2000.  960. 2000. 2000.]
# obs :  [2000. 2000.  960. 2000. 2000.]
# obs :  [2000. 2000.  960. 2000. 2000.]
# obs :  [2000. 2000.  960. 2000. 2000.]
# obs :  [2000. 2000.  960. 2000. 2000.]
# obs :  [2000. 2000.  960. 2000. 2000.]
# obs :  [2000. 2000.  960. 2000. 2000.]
# obs :  [2000. 2000.  960. 2000. 2000.]
# obs :  [2000. 2000.  960. 2000. 2000.]
# obs :  [2000. 2000.  980. 2000. 2000.]
# obs :  [2000. 2000.  980. 2000. 2000.]
# obs :  [2000. 2000.  980. 2000. 2000.]
# obs :  [2000. 2000.  980. 2000. 2000.]
# obs :  [2000. 2000.  980. 2000. 2000.]
# obs :  [2000. 2000.  980. 2000. 2000.]
# obs :  [2000. 2000.  980. 2000. 2000.]
# obs :  [2000. 2000.  980. 2000. 2000.]
# obs :  [2000. 2000.  980. 2000. 2000.]
# obs :  [2000. 2000.  980. 2000. 2000.]
# obs :  [2000. 2000.  980. 2000. 2000.]
# obs :  [2000. 2000.  980. 2000. 2000.]
# obs :  [2000. 2000.  980. 2000. 2000.]
# obs :  [2000. 2000. 1000. 2000. 2000.]
# obs :  [2000. 2000. 1000. 2000. 2000.]
# obs :  [2000. 2000. 1000. 2000. 2000.]
# obs :  [2000. 2000. 1000. 2000. 2000.]
# obs :  [2000. 2000. 1000. 2000. 2000.]
# obs :  [2000. 2000. 1000. 2000. 2000.]
# obs :  [2000. 2000. 1000. 2000. 2000.]
# obs :  [2000. 2000. 1000. 2000. 2000.]
# obs :  [2000. 2000. 1000. 2000. 2000.]
# obs :  [2000. 2000. 1000. 2000. 2000.]
# obs :  [2000. 2000. 1000. 2000. 2000.]
# obs :  [2000. 2000. 1000. 2000. 2000.]
# obs :  [2000. 2000. 1000. 2000. 2000.]
# obs :  [2000. 2000. 1000. 2000. 2000.]
# obs :  [2000. 2000. 1000. 2000. 2000.]
# obs :  [2000. 2000. 1000. 2000. 2000.]
# obs :  [2000. 2000. 1000. 2000. 2000.]
# obs :  [2000. 2000. 1000. 2000. 2000.]
# obs :  [2000. 2000. 1000. 2000. 2000.]
# obs :  [2000. 2000. 1000. 2000. 2000.]
# obs :  [2000. 2000. 1000. 2000. 2000.]
# obs :  [2000. 2000. 1000. 2000. 2000.]
# obs :  [2000. 2000. 1000. 2000. 2000.]
# obs :  [2000. 2000. 1000. 2000. 2000.]
# obs :  [2000. 2000. 1000. 2000. 2000.]
# obs :  [2000. 2000. 1000. 2000. 2000.]
# obs :  [2000. 2000. 1000. 2000. 2000.]
# obs :  [2000. 2000. 1000. 2000. 2000.]
# obs :  [2000. 2000. 1000. 2000. 2000.]
# obs :  [2000. 2000. 1000. 2000. 2000.]
# obs :  [2000. 2000. 1000. 2000. 2000.]
# obs :  [2000. 2000. 1000. 2000. 2000.]
# obs :  [2000. 2000. 1000. 2000. 2000.]
# obs :  [2000. 2000. 1000. 2000. 2000.]
# obs :  [2000. 2000. 1000. 2000. 2000.]
# obs :  [2000. 2000. 1000. 2000. 2000.]
# obs :  [2000. 2000. 1000. 2000. 2000.]
# obs :  [2000. 2000. 1020. 2000. 2000.]
# obs :  [2000. 2000. 1020. 2000. 2000.]
# obs :  [2000. 2000. 1020. 2000. 2000.]
# obs :  [2000. 2000. 1020. 2000. 2000.]
# obs :  [2000. 2000. 1020. 2000. 2000.]
# obs :  [2000. 2000. 1020. 2000. 2000.]
# obs :  [2000. 2000. 1040. 2000. 2000.]
# obs :  [2000. 2000. 1040. 2000. 2000.]
# obs :  [2000. 2000. 1040. 2000. 2000.]
# obs :  [2000. 2000. 1040. 2000. 2000.]
# obs :  [2000. 2000. 1040. 2000. 2000.]
# obs :  [2000. 2000. 1040. 2000. 2000.]
# obs :  [2000. 2000. 1040. 2000. 2000.]
# obs :  [2000. 2000. 1040. 2000. 2000.]
# obs :  [2000. 2000. 1040. 2000. 2000.]
# obs :  [2000. 2000. 1040. 2000. 2000.]
# obs :  [2000. 2000. 1040. 2000. 2000.]
# obs :  [2000. 2000. 1040. 2000. 2000.]
# obs :  [2000. 2000. 1040. 2000. 2000.]
# obs :  [2000. 2000. 1040. 2000. 2000.]
# obs :  [2000. 2000. 1040. 2000. 2000.]
# obs :  [2000. 2000. 1040. 2000. 2000.]
# obs :  [2000. 2000. 1040. 2000. 2000.]
# obs :  [2000. 2000. 1040. 2000. 2000.]
# obs :  [2000. 2000. 1040. 2000. 2000.]
# obs :  [2000. 2000. 1040. 2000. 2000.]
# obs :  [2000. 2000. 1040. 2000. 2000.]
# obs :  [2000. 2000. 1040. 2000. 2000.]
# obs :  [2000. 2000. 1040. 2000. 2000.]
# obs :  [2000. 2000. 1040. 2000. 2000.]
# obs :  [2000. 2000. 1040. 2000. 2000.]
# obs :  [2000. 2000. 1040. 2000. 2000.]
# obs :  [2000. 2000. 1040. 2000. 2000.]
# obs :  [2000. 2000. 1040. 2000. 2000.]
# obs :  [2000. 2000. 1040. 2000. 2000.]
# obs :  [2000. 2000. 1040. 2000. 2000.]
# obs :  [2000. 2000. 1040. 2000. 2000.]
# obs :  [2000. 2000. 1040. 2000. 2000.]
# obs :  [2000. 2000. 1040. 2000. 2000.]
# obs :  [2000. 2000. 1040. 2000. 2000.]
# obs :  [2000. 2000. 1040. 2000. 2000.]
# obs :  [2000. 2000. 1040. 2000. 2000.]
# obs :  [2000. 2000. 1040. 2000. 2000.]
# obs :  [2000. 2000. 1040. 2000. 2000.]
# obs :  [2000. 2000. 1060. 2000. 2000.]
# obs :  [2000. 2000. 1060. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1080. 2000. 2000.]
# obs :  [2000. 2000. 1100. 2000. 2000.]
# obs :  [2000. 2000. 1100. 2000. 2000.]
# obs :  [2000. 2000. 1100. 2000. 2000.]
# obs :  [2000. 2000. 1100. 2000. 2000.]
# obs :  [2000. 2000. 1100. 2000. 2000.]
# obs :  [2000. 2000. 1100. 2000. 2000.]
# obs :  [2000. 2000. 1100. 2000. 2000.]
# obs :  [2000. 2000. 1100. 2000. 2000.]
# obs :  [2000. 2000. 1100. 2000. 2000.]
# obs :  [2000. 2000. 1100. 2000. 2000.]
# obs :  [2000. 2000. 1100. 2000. 2000.]
# obs :  [2000. 2000. 1100. 2000. 2000.]
# obs :  [2000. 2000. 1100. 2000. 2000.]
# obs :  [2000. 2000. 1100. 2000. 2000.]
# obs :  [2000. 2000. 1120. 2000. 2000.]
# obs :  [2000. 2000. 1120. 2000. 2000.]
# obs :  [2000. 2000. 1120. 2000. 2000.]
# obs :  [2000. 2000. 1120. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1140. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1160. 2000. 2000.]
# obs :  [2000. 2000. 1180. 2000. 2000.]
# obs :  [2000. 2000. 1180. 2000. 2000.]
# obs :  [2000. 2000. 1180. 2000. 2000.]
# obs :  [2000. 2000. 1180. 2000. 2000.]
# obs :  [2000. 2000. 1180. 2000. 2000.]
# obs :  [2000. 2000. 1200. 2000. 2000.]
# obs :  [2000. 2000. 1200. 2000. 2000.]
# obs :  [2000. 2000. 1200. 2000. 2000.]
# obs :  [2000. 2000. 1200. 2000. 2000.]
# obs :  [2000. 2000. 1200. 2000. 2000.]
# obs :  [2000. 2000. 1200. 2000. 2000.]
# obs :  [2000. 2000. 1200. 2000. 2000.]
# obs :  [2000. 2000. 1200. 2000. 2000.]
# obs :  [2000. 2000. 1200. 2000. 2000.]
# obs :  [2000. 2000. 1200. 2000. 2000.]
# obs :  [2000. 2000. 1200. 2000. 2000.]
# obs :  [2000. 2000. 1200. 2000. 2000.]
# obs :  [2000. 2000. 1200. 2000. 2000.]
# obs :  [2000. 2000. 1200. 2000. 2000.]
# obs :  [2000. 2000. 1200. 2000. 2000.]
# obs :  [2000. 2000. 1200. 2000. 2000.]
# obs :  [2000. 2000. 1200. 2000. 2000.]
# obs :  [2000. 2000. 1200. 2000. 2000.]
# obs :  [2000. 2000. 1200. 2000. 2000.]
# obs :  [2000. 2000. 1200. 2000. 2000.]
# obs :  [2000. 2000. 1200. 2000. 2000.]
# obs :  [2000. 2000. 1200. 2000. 2000.]
# obs :  [2000. 2000. 1200. 2000. 2000.]
# obs :  [2000. 2000. 1200. 2000. 2000.]
# obs :  [2000. 2000. 1200. 2000. 2000.]
# obs :  [2000. 2000. 1200. 2000. 2000.]
# obs :  [2000. 2000. 1200. 2000. 2000.]
# obs :  [2000. 2000. 1200. 2000. 2000.]
# obs :  [2000. 2000. 1200. 2000. 2000.]
# obs :  [2000. 2000. 1220. 2000. 2000.]
# obs :  [2000. 2000. 1220. 2000. 2000.]
# obs :  [2000. 2000. 1220. 2000. 2000.]
# obs :  [2000. 2000. 1220. 2000. 2000.]
# obs :  [2000. 2000. 1220. 2000. 2000.]
# obs :  [2000. 2000. 1220. 2000. 2000.]
# obs :  [2000. 2000. 1220. 2000. 2000.]
# obs :  [2000. 2000. 1220. 2000. 2000.]
# obs :  [2000. 2000. 1220. 2000. 2000.]
# obs :  [2000. 2000. 1220. 2000. 2000.]
# obs :  [2000. 2000. 1220. 2000. 2000.]
# obs :  [2000. 2000. 1220. 2000. 2000.]
# obs :  [2000. 2000. 1240. 2000. 2000.]
# obs :  [2000. 2000. 1240. 2000. 2000.]
# obs :  [2000. 2000. 1240. 2000. 2000.]
# obs :  [2000. 2000. 1240. 2000. 2000.]
# obs :  [2000. 2000. 1240. 2000. 2000.]
# obs :  [2000. 2000. 1240. 2000. 2000.]
# obs :  [2000. 2000. 1240. 2000. 2000.]
# obs :  [2000. 2000. 1240. 2000. 2000.]
# obs :  [2000. 2000. 1240. 2000. 2000.]
# obs :  [2000. 2000. 1240. 2000. 2000.]
# obs :  [2000. 2000. 1240. 2000. 2000.]
# obs :  [2000. 2000. 1240. 2000. 2000.]
# obs :  [2000. 2000. 1240. 2000. 2000.]
# obs :  [2000. 2000. 1240. 2000. 2000.]
# obs :  [2000. 2000. 1240. 2000. 2000.]
# obs :  [2000. 2000. 1240. 2000. 2000.]
# obs :  [2000. 2000. 1260. 2000. 2000.]
# obs :  [2000. 2000. 1260. 2000. 2000.]
# obs :  [2000. 2000. 1260. 2000. 2000.]
# obs :  [2000. 2000. 1260. 2000. 2000.]
# obs :  [2000. 2000. 1260. 2000. 2000.]
# obs :  [2000. 2000. 1260. 2000. 2000.]
# obs :  [2000. 2000. 1260. 2000. 2000.]
# obs :  [2000. 2000. 1260. 2000. 2000.]
# obs :  [2000. 2000. 1260. 2000. 2000.]
# obs :  [2000. 2000. 1260. 2000. 2000.]
# obs :  [2000. 2000. 1260. 2000. 2000.]
# obs :  [2000. 2000. 1260. 2000. 2000.]
# obs :  [2000. 2000. 1260. 2000. 2000.]
# obs :  [2000. 2000. 1260. 2000. 2000.]
# obs :  [2000. 2000. 1280. 2000. 2000.]
# obs :  [2000. 2000. 1280. 2000. 2000.]
# obs :  [2000. 2000. 1300. 2000. 2000.]
# obs :  [2000. 2000. 1300. 2000. 2000.]
# obs :  [2000. 2000. 1300. 2000. 2000.]
# obs :  [2000. 2000. 1300. 2000. 2000.]
# obs :  [2000. 2000. 1300. 2000. 2000.]
# obs :  [2000. 2000. 1300. 2000. 2000.]
# obs :  [2000. 2000. 1300. 2000. 2000.]
# obs :  [2000. 2000. 1300. 2000. 2000.]
# obs :  [2000. 2000. 1300. 2000. 2000.]
# obs :  [2000. 2000. 1300. 2000. 2000.]
# obs :  [2000. 2000. 1300. 2000. 2000.]
# obs :  [2000. 2000. 1300. 2000. 2000.]
# obs :  [2000. 2000. 1300. 2000. 2000.]
# obs :  [2000. 2000. 1300. 2000. 2000.]
# obs :  [2000. 2000. 1300. 2000. 2000.]
# obs :  [2000. 2000. 1320. 2000. 2000.]
# obs :  [2000. 2000. 1320. 2000. 2000.]
# obs :  [2000. 2000. 1320. 2000. 2000.]
# obs :  [2000. 2000. 1320. 2000. 2000.]
# obs :  [2000. 2000. 1320. 2000. 2000.]
# obs :  [2000. 2000. 1320. 2000. 2000.]
# obs :  [2000. 2000. 1320. 2000. 2000.]
# obs :  [2000. 2000. 1320. 2000. 2000.]
# obs :  [2000. 2000. 1340. 2000. 2000.]
# obs :  [2000. 2000. 1340. 2000. 2000.]
# obs :  [2000. 2000. 1340. 2000. 2000.]
# obs :  [2000. 2000. 1340. 2000. 2000.]
# obs :  [2000. 2000. 1340. 2000. 2000.]
# obs :  [2000. 2000. 1340. 2000. 2000.]
# obs :  [2000. 2000. 1340. 2000. 2000.]
# obs :  [2000. 2000. 1340. 2000. 2000.]
# obs :  [2000. 2000. 1340. 2000. 2000.]
# obs :  [2000. 2000. 1340. 2000. 2000.]
# obs :  [2000. 2000. 1340. 2000. 2000.]
# obs :  [2000. 2000. 1340. 2000. 2000.]
# obs :  [2000. 2000. 1340. 2000. 2000.]
# obs :  [2000. 2000. 1340. 2000. 2000.]
# obs :  [2000. 2000. 1340. 2000. 2000.]
# obs :  [2000. 2000. 1340. 2000. 2000.]
# obs :  [2000. 2000. 1340. 2000. 2000.]
# obs :  [2000. 2000. 1340. 2000. 2000.]
# obs :  [2000. 2000. 1340. 2000. 2000.]
# obs :  [2000. 2000. 1340. 2000. 2000.]
# obs :  [2000. 2000. 1340. 2000. 2000.]
# obs :  [2000. 2000. 1340. 2000. 2000.]
# obs :  [2000. 2000. 1340. 2000. 2000.]
# obs :  [2000. 2000. 1340. 2000. 2000.]
# obs :  [2000. 2000. 1340. 2000. 2000.]
# obs :  [2000. 2000. 1340. 2000. 2000.]
# obs :  [2000. 2000. 1340. 2000. 2000.]
# obs :  [2000. 2000. 1340. 2000. 2000.]
# obs :  [2000. 2000. 1340. 2000. 2000.]
# obs :  [2000. 2000. 1340. 2000. 2000.]
# obs :  [2000. 2000. 1340. 2000. 2000.]
# obs :  [2000. 2000. 1340. 2000. 2000.]
# obs :  [2000. 2000. 1340. 2000. 2000.]
# obs :  [2000. 2000. 1340. 2000. 2000.]
# obs :  [2000. 2000. 1340. 2000. 2000.]
# obs :  [2000. 2000. 1340. 2000. 2000.]
# obs :  [2000. 2000. 1340. 2000. 2000.]
# obs :  [2000. 2000. 1360. 2000. 2000.]
# obs :  [2000. 2000. 1360. 2000. 2000.]
# obs :  [2000. 2000. 1360. 2000. 2000.]
# obs :  [2000. 2000. 1360. 2000. 2000.]
# obs :  [2000. 2000. 1360. 2000. 2000.]
# obs :  [2000. 2000. 1380. 2000. 2000.]
# obs :  [2000. 2000. 1380. 2000. 2000.]
# obs :  [2000. 2000. 1380. 2000. 2000.]
# obs :  [2000. 2000. 1380. 2000. 2000.]
# obs :  [2000. 2000. 1380. 2000. 2000.]
# obs :  [2000. 2000. 1380. 2000. 2000.]
# obs :  [2000. 2000. 1380. 2000. 2000.]
# obs :  [2000. 2000. 1380. 2000. 2000.]
# obs :  [2000. 2000. 1380. 2000. 2000.]
# obs :  [2000. 2000. 1380. 2000. 2000.]
# obs :  [2000. 2000. 1380. 2000. 2000.]
# obs :  [2000. 2000. 1380. 2000. 2000.]
# obs :  [2000. 2000. 1380. 2000. 2000.]
# obs :  [2000. 2000. 1380. 2000. 2000.]
# obs :  [2000. 2000. 1380. 2000. 2000.]
# obs :  [2000. 2000. 1380. 2000. 2000.]
# obs :  [2000. 2000. 1380. 2000. 2000.]
# obs :  [2000. 2000. 1380. 2000. 2000.]
# obs :  [2000. 2000. 1380. 2000. 2000.]
# obs :  [2000. 2000. 1380. 2000. 2000.]
# obs :  [2000. 2000. 1380. 2000. 2000.]
# obs :  [2000. 2000. 1380. 2000. 2000.]
# obs :  [2000. 2000. 1380. 2000. 2000.]
# obs :  [2000. 2000. 1380. 2000. 2000.]
# obs :  [2000. 2000. 1380. 2000. 2000.]
# obs :  [2000. 2000. 1380. 2000. 2000.]
# obs :  [2000. 2000. 1380. 2000. 2000.]
# obs :  [2000. 2000. 1380. 2000. 2000.]
# obs :  [2000. 2000. 1380. 2000. 2000.]
# obs :  [2000. 2000. 1380. 2000. 2000.]
# obs :  [2000. 2000. 1380. 2000. 2000.]
# obs :  [2000. 2000. 1380. 2000. 2000.]
# obs :  [2000. 2000. 1380. 2000. 2000.]
# [6200.]

# %% [markdown]
# # 3. Viz

# %%
from stable_baselines3.common.monitor import Monitor
env = Monitor(
    FlightSchedulingEnv(
        departure_times=departure_times, 
        arrival_times=arrival_times, 
        max_steps=1000
    ),
    'logs/'
)

# %%
model = PPO("MlpPolicy", env, verbose=1, tensorboard_log="logs/")
model.learn(total_timesteps=100000)
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# Logging to logs/PPO_6
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 200      |
# | time/              |          |
# |    fps             | 2165     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 1430        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.018792044 |
# |    clip_fraction        | 0.489       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.38       |
# |    explained_variance   | 0.00101     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.7e+03     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0594     |
# |    value_loss           | 3.14e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 1291        |
# |    iterations           | 3           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.019933308 |
# |    clip_fraction        | 0.438       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.33       |
# |    explained_variance   | -0.0006     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.51e+03    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.052      |
# |    value_loss           | 3.26e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 1159        |
# |    iterations           | 4           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.020443901 |
# |    clip_fraction        | 0.345       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.27       |
# |    explained_variance   | 0.000447    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 674         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0286     |
# |    value_loss           | 1.35e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 1135        |
# |    iterations           | 5           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.012636478 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.23       |
# |    explained_variance   | 0.00466     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 492         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0135     |
# |    value_loss           | 779         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 1057        |
# |    iterations           | 6           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.012388576 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.16       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 313         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0169     |
# |    value_loss           | 574         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 1011        |
# |    iterations           | 7           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.018117629 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.08       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 179         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0199     |
# |    value_loss           | 403         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 981         |
# |    iterations           | 8           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.007319576 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.03       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 124         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0127     |
# |    value_loss           | 268         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 955         |
# |    iterations           | 9           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.016958937 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.96       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 128         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0136     |
# |    value_loss           | 197         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 939         |
# |    iterations           | 10          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.011337242 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.92       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 80.7        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0066     |
# |    value_loss           | 134         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 922         |
# |    iterations           | 11          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.010375818 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.9        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 46.5        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 117         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 912         |
# |    iterations           | 12          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.011264761 |
# |    clip_fraction        | 0.087       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.86       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.7        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0061     |
# |    value_loss           | 72.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 902         |
# |    iterations           | 13          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.007912827 |
# |    clip_fraction        | 0.0778      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.84       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 44.4        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00502    |
# |    value_loss           | 84.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 890         |
# |    iterations           | 14          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.008416376 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.8        |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.6        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00704    |
# |    value_loss           | 45.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 878         |
# |    iterations           | 15          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.008291679 |
# |    clip_fraction        | 0.0968      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.78       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.4        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00625    |
# |    value_loss           | 36.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 869         |
# |    iterations           | 16          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.011721998 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.72       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.3        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00611    |
# |    value_loss           | 43.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 870         |
# |    iterations           | 17          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.014339842 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.72       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.9        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00428    |
# |    value_loss           | 26.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 880         |
# |    iterations           | 18          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.008838263 |
# |    clip_fraction        | 0.0694      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.69       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.26        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00367    |
# |    value_loss           | 22.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 889         |
# |    iterations           | 19          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.015577888 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.71       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.94        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00676    |
# |    value_loss           | 12.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 898         |
# |    iterations           | 20          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.002937749 |
# |    clip_fraction        | 0.0789      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.7        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.38        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0023     |
# |    value_loss           | 11.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 907         |
# |    iterations           | 21          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.011875959 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.72       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.58        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0079     |
# |    value_loss           | 9.21        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 915         |
# |    iterations           | 22          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.014566002 |
# |    clip_fraction        | 0.0878      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.7        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.3         |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.000848   |
# |    value_loss           | 3.29        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 200          |
# | time/                   |              |
# |    fps                  | 922          |
# |    iterations           | 23           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0071857776 |
# |    clip_fraction        | 0.0729       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.66        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.64         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00247     |
# |    value_loss           | 4.77         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 926         |
# |    iterations           | 24          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.019517448 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.58       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.41        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00654    |
# |    value_loss           | 1.86        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 931         |
# |    iterations           | 25          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.014854388 |
# |    clip_fraction        | 0.0792      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.61       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00971     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0043     |
# |    value_loss           | 3.59        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 937         |
# |    iterations           | 26          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.014959416 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.66       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00414    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00082    |
# |    value_loss           | 0.391       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 942         |
# |    iterations           | 27          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.012798788 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.64       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.38        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00422    |
# |    value_loss           | 4.81        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 200        |
# | time/                   |            |
# |    fps                  | 948        |
# |    iterations           | 28         |
# |    time_elapsed         | 60         |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.01490131 |
# |    clip_fraction        | 0.12       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.64      |
# |    explained_variance   | 1.19e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0054    |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.00337   |
# |    value_loss           | 1.66       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 953         |
# |    iterations           | 29          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.009881257 |
# |    clip_fraction        | 0.0393      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.65       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.93        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00121    |
# |    value_loss           | 6.13        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 200          |
# | time/                   |              |
# |    fps                  | 958          |
# |    iterations           | 30           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0058244816 |
# |    clip_fraction        | 0.0755       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.66        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.14         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00246     |
# |    value_loss           | 1.74         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 963         |
# |    iterations           | 31          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.012553863 |
# |    clip_fraction        | 0.0576      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.68       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0011     |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -3.11e-05   |
# |    value_loss           | 3.23e-06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 967         |
# |    iterations           | 32          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.010745761 |
# |    clip_fraction        | 0.0859      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.66       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0164      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00216    |
# |    value_loss           | 5.93e-07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 972         |
# |    iterations           | 33          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.011275321 |
# |    clip_fraction        | 0.0863      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.65       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0124      |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00352    |
# |    value_loss           | 4.11e-07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 976         |
# |    iterations           | 34          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.018260945 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.66       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00418    |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00734    |
# |    value_loss           | 2.08        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 200        |
# | time/                   |            |
# |    fps                  | 980        |
# |    iterations           | 35         |
# |    time_elapsed         | 73         |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.01081364 |
# |    clip_fraction        | 0.0977     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.61      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00466    |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.000427  |
# |    value_loss           | 2.47e-06   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 985         |
# |    iterations           | 36          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.016581044 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.5        |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0221      |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00536    |
# |    value_loss           | 1.36e-07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 989         |
# |    iterations           | 37          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.018571887 |
# |    clip_fraction        | 0.257       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.55       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0248      |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0036     |
# |    value_loss           | 0.738       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 992         |
# |    iterations           | 38          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.017119268 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.56       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0298     |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00325    |
# |    value_loss           | 1.13e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 993         |
# |    iterations           | 39          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.014438966 |
# |    clip_fraction        | 0.0677      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.4         |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00297    |
# |    value_loss           | 3.47        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 200        |
# | time/                   |            |
# |    fps                  | 995        |
# |    iterations           | 40         |
# |    time_elapsed         | 82         |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.01884554 |
# |    clip_fraction        | 0.253      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.53      |
# |    explained_variance   | 5.96e-08   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0313     |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.00148   |
# |    value_loss           | 5.08e-05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 997         |
# |    iterations           | 41          |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.010148998 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.58       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00484    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.001      |
# |    value_loss           | 0.57        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 998         |
# |    iterations           | 42          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.010690594 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.63       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0226      |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00236    |
# |    value_loss           | 0.738       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 1001        |
# |    iterations           | 43          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.006340873 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.65       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0205     |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.000138   |
# |    value_loss           | 1.05e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 1004        |
# |    iterations           | 44          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.011748031 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.65       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0066      |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00257    |
# |    value_loss           | 2.32        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 1006        |
# |    iterations           | 45          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.010596257 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.62       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00477     |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00473    |
# |    value_loss           | 2.33        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 1009        |
# |    iterations           | 46          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.013919232 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.65       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00799     |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00243    |
# |    value_loss           | 1.09e-06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 1011        |
# |    iterations           | 47          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.011097511 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.69       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00571     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00451    |
# |    value_loss           | 2.35e-08    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 1014        |
# |    iterations           | 48          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.006814152 |
# |    clip_fraction        | 0.0949      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.69       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0521      |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00335    |
# |    value_loss           | 1.31        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 1015        |
# |    iterations           | 49          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.015090919 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.68       |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.02       |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00681    |
# |    value_loss           | 0.201       |
# -----------------------------------------

# %%
for _ in range(10):
    obs = env.reset()[0]
    total_reward = 0
    done = False
    while not done:
        action, _ = model.predict(obs)
        #action = [0]
        obs, reward, done, _, _ = env.step(action)
        #print('action : ', action)
        #print('obs : ', obs)
        #print('reward : ', reward)
        total_reward += reward
    print(total_reward)
env.close()
# Out:
# 6820
# 6820
# 6820
# 6820
# 6820
# 6820
# 6820
# 6820
# 6820
# 6820

# %%
# %tensorboard --logdir=logs/
# Out:
# 'tensorboard' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# # 4. Revenue estimation

# %%
import random
import pandas as pd
from datetime import datetime, timedelta

def generate_random_flight_schedule(N):
    flight_schedule = []

    # Définir une plage horaire pour les vols (par exemple, une journée)
    start_time = datetime.strptime("08:00", "%H:%M")
    end_time = datetime.strptime("22:00", "%H:%M")

    for _ in range(N):
        # Générer des horaires de départ et d'arrivée aléatoires
        departure_time = start_time + timedelta(minutes=random.randint(0, (end_time - start_time).seconds // 60))
        arrival_time = departure_time + timedelta(minutes=random.randint(30, 40))  # Exemple : vol de 30 à 240 minutes

        # Ajouter le vol à la liste
        flight_schedule.append((departure_time, arrival_time, random.choice([-1, 1])))

    # Trier la liste par horaire de départ
    flight_schedule.sort(key=lambda x: x[0])

    return pd.DataFrame(flight_schedule, columns=['departure', 'arrival', 'way'])

# Exemple : Générer un planning de départ aléatoire avec 5 vols
random_schedule = generate_random_flight_schedule(2)
random_schedule
# Out:
#             departure             arrival  way
# 0 1900-01-01 13:43:00 1900-01-01 14:17:00   -1
# 1 1900-01-01 15:35:00 1900-01-01 16:12:00    1

# %%
# Créer un dictionnaire pour stocker les valeurs aléatoires pour chaque paire de vols de sens opposé
lambdas = {}

# Parcourir le DataFrame pour chaque vol de départ
for i, departure_flight in random_schedule[random_schedule['way'] == 1].iterrows():
    # Sélectionner tous les vols d'arrivée de sens opposé
    arrival_flights = random_schedule[(random_schedule['way'] == -1) & (random_schedule.index != i)]

    # Associer une valeur aléatoire pour chaque paire de vols
    for _, arrival_flight in arrival_flights.iterrows():
        lambdas[(departure_flight.name, arrival_flight.name)] = random.randint(0, 100)

# %%
import pandas as pd
from datetime import timedelta

def calculate_feasible_connections(df, min_connection_time, max_connection_time):
    # Créer une copie du DataFrame pour les départs du hub
    departures = df[df['way'] == 1].copy()

    # Créer une copie du DataFrame pour les arrivées au hub
    arrivals = df[df['way'] == -1].copy()

    # Initialiser un DataFrame pour les connexions faisables
    feasible_connections = pd.DataFrame(columns=['departure_flight', 'arrival_flight', 'cnx_time'])

    # Parcourir tous les vols de départ
    for i in range(len(arrivals)):
        arrival_flight = arrivals.iloc[i]
        
        # Filtrer les vols d'arrivée qui ont un sens opposé et un temps de connexion faisable
        possible_departures = departures[
            (departures['departure'] >= arrival_flight['arrival'] + timedelta(minutes=min_connection_time)) &
            (departures['departure'] <= arrival_flight['arrival'] + timedelta(minutes=max_connection_time))
        ]

        # Ajouter les connexions faisables au DataFrame
        for _, departure_flight in possible_departures.iterrows():
            connection_time = departure_flight['departure'] - arrival_flight['arrival']
            connection_info = {
                'departure_flight': departure_flight.name,
                'arrival_flight': arrival_flight.name,
                'cnx_time': connection_time,
                'cnx_time_min' : int(connection_time.total_seconds() / 60)
            }
            feasible_connections = pd.concat([feasible_connections, pd.DataFrame([connection_info])], ignore_index=True)

    return feasible_connections

min_connection_time = 60
max_connection_time = 480

connections = calculate_feasible_connections(random_schedule, min_connection_time, max_connection_time)
print(connections)
# Out:
#   departure_flight arrival_flight        cnx_time  cnx_time_min
# 0                1              0 0 days 01:18:00          78.0

# %%
def preference_curve(x):
    if 60 <= x <= 120:
        return 0.5 + 0.5 * (x - 60) / 60
    elif 120 < x < 480:
        return 1 - 0.5 * (x - 120) / 360
    else:
        return 0
    
connections['z'] = connections['cnx_time_min'].apply(lambda x : preference_curve(x))

# %%
connections['lambdas'] = connections.apply(lambda x : lambdas[(x.departure_flight, x.arrival_flight)], axis=1)
connections['revenue'] = connections['z'] * connections['lambdas']
# Out:
#   departure_flight arrival_flight        cnx_time  cnx_time_min     z
# 0                1              0 0 days 01:18:00          78.0  0.65

# %%
def calculate_revenue(self):
    flights = self.current_state
    connections = calculate_feasible_connections()
